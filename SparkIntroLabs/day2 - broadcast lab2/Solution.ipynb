# %% [markdown]
# # Answers: Custom Accumulators Lab

# %% [markdown]
# ### Exercise Part 1

# %%
class AccumSet(AccumulatorParam):
    def zero(self, initial):
      return set()

    def addInPlace(self, s1, s2):
      return s1 | s2

# %% [markdown]
# ### Exercise Part 2

# %%
def update_set(i):
  global unique_numbers
  unique_numbers += set([i])

rdd.foreach(update_set)
